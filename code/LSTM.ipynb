# %%
import librosa
import math
import os
import re

import numpy as np

# %%
class GenreFeatureData:

    "Music audio features for genre classification"
    hop_length = None
    genre_list = [
        "classical",
        "country",
        "disco",
        "hiphop",
        "jazz",
        "metal",
        "pop",
        "reggae",
    ]

    dir_trainfolder = "../data/gtzan/_train"
    dir_devfolder = "../data/gtzan/_validation"
    dir_testfolder = "../data/gtzan/_test"
    dir_all_files = "../data/gtzan"

    train_X_preprocessed_data = "../data/gtzan/data_train_input.npy"
    train_Y_preprocessed_data = "../data/gtzan/data_train_target.npy"
    dev_X_preprocessed_data = "../data/gtzan/data_validation_input.npy"
    dev_Y_preprocessed_data = "../data/gtzan/data_validation_target.npy"
    test_X_preprocessed_data = "../data/gtzan/data_test_input.npy"
    test_Y_preprocessed_data = "../data/gtzan/data_test_target.npy"

    train_X = train_Y = None
    dev_X = dev_Y = None
    test_X = test_Y = None

    def __init__(self):
        self.hop_length = 512

        self.timeseries_length_list = []
        self.trainfiles_list = self.path_to_audiofiles(self.dir_trainfolder)
        self.devfiles_list = self.path_to_audiofiles(self.dir_devfolder)
        self.testfiles_list = self.path_to_audiofiles(self.dir_testfolder)

        self.all_files_list = []
        self.all_files_list.extend(self.trainfiles_list)
        self.all_files_list.extend(self.devfiles_list)
        self.all_files_list.extend(self.testfiles_list)

        # compute minimum timeseries length, slow to compute, caching pre-computed value of 1290
        # self.precompute_min_timeseries_len()
        # print("min(self.timeseries_length_list) ==" + str(min(self.timeseries_length_list)))
        # self.timeseries_length = min(self.timeseries_length_list)

        self.timeseries_length = (
            128
        )   # sequence length == 128, default fftsize == 2048 & hop == 512 @ SR of 22050
        #  equals 128 overlapped windows that cover approx ~3.065 seconds of audio, which is a bit small!

    def load_preprocess_data(self):
        print("[DEBUG] total number of files: " + str(len(self.timeseries_length_list)))

        # Training set
        self.train_X, self.train_Y = self.extract_audio_features(self.trainfiles_list)
        with open(self.train_X_preprocessed_data, "wb") as f:
            np.save(f, self.train_X)
        with open(self.train_Y_preprocessed_data, "wb") as f:
            self.train_Y = self.one_hot(self.train_Y)
            np.save(f, self.train_Y)

        # Validation set
        self.dev_X, self.dev_Y = self.extract_audio_features(self.devfiles_list)
        with open(self.dev_X_preprocessed_data, "wb") as f:
            np.save(f, self.dev_X)
        with open(self.dev_Y_preprocessed_data, "wb") as f:
            self.dev_Y = self.one_hot(self.dev_Y)
            np.save(f, self.dev_Y)

        # Test set
        self.test_X, self.test_Y = self.extract_audio_features(self.testfiles_list)
        with open(self.test_X_preprocessed_data, "wb") as f:
            np.save(f, self.test_X)
        with open(self.test_Y_preprocessed_data, "wb") as f:
            self.test_Y = self.one_hot(self.test_Y)
            np.save(f, self.test_Y)

    def load_deserialize_data(self):

        self.train_X = np.load(self.train_X_preprocessed_data)
        self.train_Y = np.load(self.train_Y_preprocessed_data)

        self.dev_X = np.load(self.dev_X_preprocessed_data)
        self.dev_Y = np.load(self.dev_Y_preprocessed_data)

        self.test_X = np.load(self.test_X_preprocessed_data)
        self.test_Y = np.load(self.test_Y_preprocessed_data)

    def precompute_min_timeseries_len(self):
        for file in self.all_files_list:
            print("Loading " + str(file))
            y, sr = librosa.load(file)
            self.timeseries_length_list.append(math.ceil(len(y) / self.hop_length))

    def extract_audio_features(self, list_of_audiofiles):

        data = np.zeros(
            (len(list_of_audiofiles), self.timeseries_length, 33), dtype=np.float64
        )
        target = []

        for i, file in enumerate(list_of_audiofiles):
            y, sr = librosa.load(file)
            mfcc = librosa.feature.mfcc(
                y=y, sr=sr, hop_length=self.hop_length, n_mfcc=13
            )
            spectral_center = librosa.feature.spectral_centroid(
                y=y, sr=sr, hop_length=self.hop_length
            )
            chroma = librosa.feature.chroma_stft(y=y, sr=sr, hop_length=self.hop_length)
            spectral_contrast = librosa.feature.spectral_contrast(
                y=y, sr=sr, hop_length=self.hop_length
            )

            splits = re.split("[ .]", file)
            genre = re.split("[ /]", splits[1])[3]
            target.append(genre)

            data[i, :, 0:13] = mfcc.T[0:self.timeseries_length, :]
            data[i, :, 13:14] = spectral_center.T[0:self.timeseries_length, :]
            data[i, :, 14:26] = chroma.T[0:self.timeseries_length, :]
            data[i, :, 26:33] = spectral_contrast.T[0:self.timeseries_length, :]

            print(
                "Extracted features audio track %i of %i."
                % (i + 1, len(list_of_audiofiles))
            )

        return data, np.expand_dims(np.asarray(target), axis=1)

    def one_hot(self, Y_genre_strings):
        y_one_hot = np.zeros((Y_genre_strings.shape[0], len(self.genre_list)))
        for i, genre_string in enumerate(Y_genre_strings):
            index = self.genre_list.index(genre_string)
            y_one_hot[i, index] = 1
        return y_one_hot

    @staticmethod
    def path_to_audiofiles(dir_folder):
        list_of_audio = []
        for file in os.listdir(dir_folder):
            if file.endswith(".au"):
                directory = "%s/%s" % (dir_folder, file)
                list_of_audio.append(directory)
        return list_of_audio

# %%
import logging
import os
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from keras.optimizers import Adam


# set logging level
logging.getLogger("tensorflow").setLevel(logging.ERROR)

genre_features = GenreFeatureData()

# if all of the preprocessed files do not exist, regenerate them all for self-consistency
if (
    os.path.isfile(genre_features.train_X_preprocessed_data)
    and os.path.isfile(genre_features.train_Y_preprocessed_data)
    and os.path.isfile(genre_features.dev_X_preprocessed_data)
    and os.path.isfile(genre_features.dev_Y_preprocessed_data)
    and os.path.isfile(genre_features.test_X_preprocessed_data)
    and os.path.isfile(genre_features.test_Y_preprocessed_data)
):
    print("Preprocessed files exist, deserializing npy files")
    genre_features.load_deserialize_data()
else:
    print("Preprocessing raw audio files")
    genre_features.load_preprocess_data()

print("Training X shape: " + str(genre_features.train_X.shape))
print("Training Y shape: " + str(genre_features.train_Y.shape))
print("Dev X shape: " + str(genre_features.dev_X.shape))
print("Dev Y shape: " + str(genre_features.dev_Y.shape))
print("Test X shape: " + str(genre_features.test_X.shape))
print("Test Y shape: " + str(genre_features.test_Y.shape))

input_shape = (genre_features.train_X.shape[1], genre_features.train_X.shape[2])
print("Build LSTM RNN model ...")
model = Sequential()

model.add(LSTM(units=128, dropout=0.05, recurrent_dropout=0.35, return_sequences=True, input_shape=input_shape))
model.add(LSTM(units=32,  dropout=0.05, recurrent_dropout=0.35, return_sequences=False))
model.add(Dense(units=genre_features.train_Y.shape[1], activation="softmax"))

print("Compiling ...")
# Keras optimizer defaults:
# Adam   : lr=0.001, beta_1=0.9,  beta_2=0.999, epsilon=1e-8, decay=0.
# RMSprop: lr=0.001, rho=0.9,                   epsilon=1e-8, decay=0.
# SGD    : lr=0.01,  momentum=0.,                             decay=0.
opt = Adam()
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
model.summary()

print("Training ...")
batch_size = 35  # num of training examples per minibatch
num_epochs = 400
model.fit(
    genre_features.train_X,
    genre_features.train_Y,
    batch_size=batch_size,
    epochs=num_epochs,
)

print("\nValidating ...")
score, accuracy = model.evaluate(
    genre_features.dev_X, genre_features.dev_Y, batch_size=batch_size, verbose=1
)
print("Dev loss:  ", score)
print("Dev accuracy:  ", accuracy)


print("\nTesting ...")
score, accuracy = model.evaluate(
    genre_features.test_X, genre_features.test_Y, batch_size=batch_size, verbose=1
)
print("Test loss:  ", score)
print("Test accuracy:  ", accuracy)

# Creates a HDF5 file 'lstm_genre_classifier.h5'
model_filename = "lstm_genre_classifier_lstm.h5"
print("\nSaving model: " + model_filename)
model.save(model_filename)
# Out:
# Preprocessed files exist, deserializing npy files
# Training X shape: (420, 128, 33)
# Training Y shape: (420, 8)
# Dev X shape: (120, 128, 33)
# Dev Y shape: (120, 8)
# Test X shape: (60, 128, 33)
# Test Y shape: (60, 8)
# Build LSTM RNN model ...
# Compiling ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128, 128)          82944
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                20608
# _________________________________________________________________
# dense (Dense)                (None, 8)                 264
# =================================================================
# Total params: 103,816
# Trainable params: 103,816
# Non-trainable params: 0
# _________________________________________________________________
# Training ...
# Epoch 1/400
# 12/12 [==============================] - 5s 394ms/step - loss: 2.0007 - accuracy: 0.1738
# Epoch 2/400
# 12/12 [==============================] - 4s 349ms/step - loss: 1.7508 - accuracy: 0.3524
# Epoch 3/400
# 12/12 [==============================] - 4s 295ms/step - loss: 1.5508 - accuracy: 0.4667
# Epoch 4/400
# 12/12 [==============================] - 4s 294ms/step - loss: 1.3639 - accuracy: 0.5286
# Epoch 5/400
# 12/12 [==============================] - 3s 267ms/step - loss: 1.2454 - accuracy: 0.5524
# Epoch 6/400
# 12/12 [==============================] - 3s 265ms/step - loss: 1.2178 - accuracy: 0.5476
# Epoch 7/400
# 12/12 [==============================] - 3s 246ms/step - loss: 1.1095 - accuracy: 0.6000
# Epoch 8/400
# 12/12 [==============================] - 3s 230ms/step - loss: 1.1123 - accuracy: 0.5690
# Epoch 9/400
# 12/12 [==============================] - 3s 228ms/step - loss: 1.0793 - accuracy: 0.5595
# Epoch 10/400
# 12/12 [==============================] - 3s 229ms/step - loss: 1.0520 - accuracy: 0.5667
# Epoch 11/400
# 12/12 [==============================] - 3s 221ms/step - loss: 1.0231 - accuracy: 0.6000
# Epoch 12/400
# 12/12 [==============================] - 3s 220ms/step - loss: 1.0709 - accuracy: 0.5714
# Epoch 13/400
# 12/12 [==============================] - 3s 222ms/step - loss: 1.0864 - accuracy: 0.5762
# Epoch 14/400
# 12/12 [==============================] - 3s 213ms/step - loss: 0.9516 - accuracy: 0.6429
# Epoch 15/400
# 12/12 [==============================] - 3s 215ms/step - loss: 1.1331 - accuracy: 0.5810
# Epoch 16/400
# 12/12 [==============================] - 3s 216ms/step - loss: 1.2919 - accuracy: 0.5071
# Epoch 17/400
# 12/12 [==============================] - 3s 209ms/step - loss: 1.0933 - accuracy: 0.6119
# Epoch 18/400
# 12/12 [==============================] - 3s 218ms/step - loss: 1.0478 - accuracy: 0.5976
# Epoch 19/400
# 12/12 [==============================] - 3s 212ms/step - loss: 1.0050 - accuracy: 0.5976
# Epoch 20/400
# 12/12 [==============================] - 3s 220ms/step - loss: 0.9627 - accuracy: 0.6381
# Epoch 21/400
# 12/12 [==============================] - 3s 223ms/step - loss: 0.9319 - accuracy: 0.6500
# Epoch 22/400
# 12/12 [==============================] - 3s 230ms/step - loss: 0.9120 - accuracy: 0.6524
# Epoch 23/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.8744 - accuracy: 0.6690
# Epoch 24/400
# 12/12 [==============================] - 3s 235ms/step - loss: 0.8517 - accuracy: 0.6833
# Epoch 25/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.8835 - accuracy: 0.6429
# Epoch 26/400
# 12/12 [==============================] - 3s 242ms/step - loss: 0.8779 - accuracy: 0.6762
# Epoch 27/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.8436 - accuracy: 0.6595
# Epoch 28/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.8345 - accuracy: 0.7071
# Epoch 29/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.8461 - accuracy: 0.6643
# Epoch 30/400
# 12/12 [==============================] - 3s 242ms/step - loss: 0.8354 - accuracy: 0.6833
# Epoch 31/400
# 12/12 [==============================] - 3s 238ms/step - loss: 0.8679 - accuracy: 0.6524
# Epoch 32/400
# 12/12 [==============================] - 3s 233ms/step - loss: 0.8766 - accuracy: 0.6690
# Epoch 33/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.8799 - accuracy: 0.6595
# Epoch 34/400
# 12/12 [==============================] - 3s 235ms/step - loss: 0.7984 - accuracy: 0.6905
# Epoch 35/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.7790 - accuracy: 0.7048
# Epoch 36/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.7399 - accuracy: 0.7310
# Epoch 37/400
# 12/12 [==============================] - 3s 269ms/step - loss: 0.7983 - accuracy: 0.7024
# Epoch 38/400
# 12/12 [==============================] - 3s 270ms/step - loss: 0.7838 - accuracy: 0.6881
# Epoch 39/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.7542 - accuracy: 0.7071
# Epoch 40/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.7556 - accuracy: 0.7214
# Epoch 41/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.7691 - accuracy: 0.7214
# Epoch 42/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.7616 - accuracy: 0.7024
# Epoch 43/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.7576 - accuracy: 0.7190
# Epoch 44/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.7548 - accuracy: 0.7071
# Epoch 45/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.7399 - accuracy: 0.7167
# Epoch 46/400
# 12/12 [==============================] - 3s 233ms/step - loss: 0.7146 - accuracy: 0.7357
# Epoch 47/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.6798 - accuracy: 0.7190
# Epoch 48/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.7089 - accuracy: 0.7167
# Epoch 49/400
# 12/12 [==============================] - 3s 226ms/step - loss: 0.6493 - accuracy: 0.7429
# Epoch 50/400
# 12/12 [==============================] - 3s 232ms/step - loss: 0.6687 - accuracy: 0.7429
# Epoch 51/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.6271 - accuracy: 0.7714
# Epoch 52/400
# 12/12 [==============================] - 3s 225ms/step - loss: 0.6243 - accuracy: 0.7524
# Epoch 53/400
# 12/12 [==============================] - 3s 219ms/step - loss: 0.6776 - accuracy: 0.7262
# Epoch 54/400
# 12/12 [==============================] - 3s 215ms/step - loss: 0.6359 - accuracy: 0.7738
# Epoch 55/400
# 12/12 [==============================] - 3s 214ms/step - loss: 0.5911 - accuracy: 0.7595
# Epoch 56/400
# 12/12 [==============================] - 3s 221ms/step - loss: 0.6171 - accuracy: 0.7571
# Epoch 57/400
# 12/12 [==============================] - 3s 213ms/step - loss: 0.6135 - accuracy: 0.7786
# Epoch 58/400
# 12/12 [==============================] - 3s 216ms/step - loss: 0.6349 - accuracy: 0.7524
# Epoch 59/400
# 12/12 [==============================] - 3s 211ms/step - loss: 0.6022 - accuracy: 0.7667
# Epoch 60/400
# 12/12 [==============================] - 3s 213ms/step - loss: 0.6309 - accuracy: 0.7548
# Epoch 61/400
# 12/12 [==============================] - 3s 216ms/step - loss: 0.5809 - accuracy: 0.7810
# Epoch 62/400
# 12/12 [==============================] - 3s 220ms/step - loss: 0.6734 - accuracy: 0.7571
# Epoch 63/400
# 12/12 [==============================] - 3s 223ms/step - loss: 0.5497 - accuracy: 0.8167
# Epoch 64/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.5396 - accuracy: 0.8071
# Epoch 65/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.5863 - accuracy: 0.7643
# Epoch 66/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.5944 - accuracy: 0.7714
# Epoch 67/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.5616 - accuracy: 0.7810
# Epoch 68/400
# 12/12 [==============================] - 3s 237ms/step - loss: 0.5793 - accuracy: 0.7881
# Epoch 69/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.5453 - accuracy: 0.8024
# Epoch 70/400
# 12/12 [==============================] - 3s 227ms/step - loss: 0.5859 - accuracy: 0.7905
# Epoch 71/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.6041 - accuracy: 0.7738
# Epoch 72/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.5981 - accuracy: 0.7738
# Epoch 73/400
# 12/12 [==============================] - 3s 232ms/step - loss: 0.5758 - accuracy: 0.7976
# Epoch 74/400
# 12/12 [==============================] - 3s 222ms/step - loss: 0.5265 - accuracy: 0.8024
# Epoch 75/400
# 12/12 [==============================] - 3s 225ms/step - loss: 0.5309 - accuracy: 0.8000
# Epoch 76/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.5459 - accuracy: 0.8000
# Epoch 77/400
# 12/12 [==============================] - 3s 234ms/step - loss: 0.5420 - accuracy: 0.8024
# Epoch 78/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.5154 - accuracy: 0.8167
# Epoch 79/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.5175 - accuracy: 0.7762
# Epoch 80/400
# 12/12 [==============================] - 3s 285ms/step - loss: 0.4816 - accuracy: 0.8262
# Epoch 81/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.5009 - accuracy: 0.8024
# Epoch 82/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.5053 - accuracy: 0.8048
# Epoch 83/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.5435 - accuracy: 0.7952
# Epoch 84/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.5394 - accuracy: 0.7810
# Epoch 85/400
# 12/12 [==============================] - 3s 247ms/step - loss: 0.4556 - accuracy: 0.8476
# Epoch 86/400
# 12/12 [==============================] - 3s 235ms/step - loss: 0.4742 - accuracy: 0.8214
# Epoch 87/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.5185 - accuracy: 0.8095
# Epoch 88/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.5348 - accuracy: 0.7643
# Epoch 89/400
# 12/12 [==============================] - 3s 237ms/step - loss: 0.4642 - accuracy: 0.8190
# Epoch 90/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.4394 - accuracy: 0.8381
# Epoch 91/400
# 12/12 [==============================] - 4s 296ms/step - loss: 0.4784 - accuracy: 0.8167
# Epoch 92/400
# 12/12 [==============================] - 3s 273ms/step - loss: 0.5017 - accuracy: 0.8095
# Epoch 93/400
# 12/12 [==============================] - 4s 297ms/step - loss: 0.4265 - accuracy: 0.8452
# Epoch 94/400
# 12/12 [==============================] - 3s 288ms/step - loss: 0.5591 - accuracy: 0.7738
# Epoch 95/400
# 12/12 [==============================] - 3s 290ms/step - loss: 0.4995 - accuracy: 0.8048
# Epoch 96/400
# 12/12 [==============================] - 3s 283ms/step - loss: 0.4825 - accuracy: 0.8119
# Epoch 97/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.4296 - accuracy: 0.8286
# Epoch 98/400
# 12/12 [==============================] - 3s 247ms/step - loss: 0.4208 - accuracy: 0.8405
# Epoch 99/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.4155 - accuracy: 0.8452
# Epoch 100/400
# 12/12 [==============================] - 3s 238ms/step - loss: 0.4160 - accuracy: 0.8405
# Epoch 101/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.4535 - accuracy: 0.8214
# Epoch 102/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.4417 - accuracy: 0.8500
# Epoch 103/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.3964 - accuracy: 0.8286
# Epoch 104/400
# 12/12 [==============================] - 3s 224ms/step - loss: 0.3668 - accuracy: 0.8500
# Epoch 105/400
# 12/12 [==============================] - 3s 226ms/step - loss: 0.3637 - accuracy: 0.8643
# Epoch 106/400
# 12/12 [==============================] - 3s 227ms/step - loss: 0.3672 - accuracy: 0.8571
# Epoch 107/400
# 12/12 [==============================] - 3s 227ms/step - loss: 0.4065 - accuracy: 0.8405
# Epoch 108/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.5156 - accuracy: 0.7952
# Epoch 109/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.4102 - accuracy: 0.8476
# Epoch 110/400
# 12/12 [==============================] - 3s 237ms/step - loss: 0.3756 - accuracy: 0.8738
# Epoch 111/400
# 12/12 [==============================] - 3s 230ms/step - loss: 0.3513 - accuracy: 0.8690
# Epoch 112/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.3404 - accuracy: 0.8667
# Epoch 113/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.3974 - accuracy: 0.8714
# Epoch 114/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.3958 - accuracy: 0.8738
# Epoch 115/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.3527 - accuracy: 0.8571
# Epoch 116/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.3481 - accuracy: 0.8810
# Epoch 117/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.3254 - accuracy: 0.8714
# Epoch 118/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.3905 - accuracy: 0.8405
# Epoch 119/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.3709 - accuracy: 0.8476
# Epoch 120/400
# 12/12 [==============================] - 3s 260ms/step - loss: 0.3748 - accuracy: 0.8524
# Epoch 121/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.3548 - accuracy: 0.8762
# Epoch 122/400
# 12/12 [==============================] - 3s 256ms/step - loss: 0.4244 - accuracy: 0.8429
# Epoch 123/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.3714 - accuracy: 0.8714
# Epoch 124/400
# 12/12 [==============================] - 3s 246ms/step - loss: 0.3633 - accuracy: 0.8667
# Epoch 125/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.3657 - accuracy: 0.8714
# Epoch 126/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.3162 - accuracy: 0.8643
# Epoch 127/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.3391 - accuracy: 0.8738
# Epoch 128/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.3382 - accuracy: 0.8786
# Epoch 129/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.2985 - accuracy: 0.8857
# Epoch 130/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.2696 - accuracy: 0.9119
# Epoch 131/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.3141 - accuracy: 0.8857
# Epoch 132/400
# 12/12 [==============================] - 3s 274ms/step - loss: 0.4011 - accuracy: 0.8429
# Epoch 133/400
# 12/12 [==============================] - 4s 301ms/step - loss: 0.3552 - accuracy: 0.8619
# Epoch 134/400
# 12/12 [==============================] - 5s 376ms/step - loss: 0.3336 - accuracy: 0.8881
# Epoch 135/400
# 12/12 [==============================] - 4s 326ms/step - loss: 0.2695 - accuracy: 0.8976
# Epoch 136/400
# 12/12 [==============================] - 3s 289ms/step - loss: 0.2706 - accuracy: 0.9167
# Epoch 137/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.2904 - accuracy: 0.8905
# Epoch 138/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.3597 - accuracy: 0.8714
# Epoch 139/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.3603 - accuracy: 0.8762
# Epoch 140/400
# 12/12 [==============================] - 4s 292ms/step - loss: 0.2979 - accuracy: 0.8905
# Epoch 141/400
# 12/12 [==============================] - 4s 319ms/step - loss: 0.2929 - accuracy: 0.8905
# Epoch 142/400
# 12/12 [==============================] - 3s 268ms/step - loss: 0.2661 - accuracy: 0.8952
# Epoch 143/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.2786 - accuracy: 0.9048
# Epoch 144/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.2988 - accuracy: 0.8881
# Epoch 145/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.2704 - accuracy: 0.9095
# Epoch 146/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.3201 - accuracy: 0.8857
# Epoch 147/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.3288 - accuracy: 0.8667
# Epoch 148/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.2746 - accuracy: 0.9048
# Epoch 149/400
# 12/12 [==============================] - 3s 264ms/step - loss: 0.2455 - accuracy: 0.9190
# Epoch 150/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.2776 - accuracy: 0.9048
# Epoch 151/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.2975 - accuracy: 0.8810
# Epoch 152/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.2745 - accuracy: 0.8976
# Epoch 153/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.2731 - accuracy: 0.9000
# Epoch 154/400
# 12/12 [==============================] - 3s 285ms/step - loss: 0.2939 - accuracy: 0.8929
# Epoch 155/400
# 12/12 [==============================] - 3s 269ms/step - loss: 0.2620 - accuracy: 0.9048
# Epoch 156/400
# 12/12 [==============================] - 3s 262ms/step - loss: 0.2951 - accuracy: 0.8833
# Epoch 157/400
# 12/12 [==============================] - 3s 274ms/step - loss: 0.2601 - accuracy: 0.9095
# Epoch 158/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.2376 - accuracy: 0.9119
# Epoch 159/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.2655 - accuracy: 0.9024
# Epoch 160/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.2620 - accuracy: 0.9095
# Epoch 161/400
# 12/12 [==============================] - 3s 247ms/step - loss: 0.2459 - accuracy: 0.9143
# Epoch 162/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.2479 - accuracy: 0.9214
# Epoch 163/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.2378 - accuracy: 0.9262
# Epoch 164/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.2302 - accuracy: 0.9238
# Epoch 165/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.2583 - accuracy: 0.9095
# Epoch 166/400
# 12/12 [==============================] - 3s 246ms/step - loss: 0.3198 - accuracy: 0.8833
# Epoch 167/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.2608 - accuracy: 0.9048
# Epoch 168/400
# 12/12 [==============================] - 3s 249ms/step - loss: 0.2641 - accuracy: 0.9119
# Epoch 169/400
# 12/12 [==============================] - 3s 232ms/step - loss: 0.2110 - accuracy: 0.9262
# Epoch 170/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.2537 - accuracy: 0.9071
# Epoch 171/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.2648 - accuracy: 0.8952
# Epoch 172/400
# 12/12 [==============================] - 3s 253ms/step - loss: 0.3485 - accuracy: 0.8833
# Epoch 173/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.3259 - accuracy: 0.8881
# Epoch 174/400
# 12/12 [==============================] - 3s 271ms/step - loss: 0.2833 - accuracy: 0.9024
# Epoch 175/400
# 12/12 [==============================] - 3s 271ms/step - loss: 0.2532 - accuracy: 0.9167
# Epoch 176/400
# 12/12 [==============================] - 3s 273ms/step - loss: 0.2894 - accuracy: 0.8905
# Epoch 177/400
# 12/12 [==============================] - 3s 288ms/step - loss: 0.2590 - accuracy: 0.9071
# Epoch 178/400
# 12/12 [==============================] - 4s 304ms/step - loss: 0.2132 - accuracy: 0.9238
# Epoch 179/400
# 12/12 [==============================] - 4s 320ms/step - loss: 0.2331 - accuracy: 0.9167
# Epoch 180/400
# 12/12 [==============================] - 4s 295ms/step - loss: 0.2246 - accuracy: 0.9167
# Epoch 181/400
# 12/12 [==============================] - 4s 299ms/step - loss: 0.2444 - accuracy: 0.9119
# Epoch 182/400
# 12/12 [==============================] - 3s 280ms/step - loss: 0.2998 - accuracy: 0.8881
# Epoch 183/400
# 12/12 [==============================] - 3s 285ms/step - loss: 0.2593 - accuracy: 0.8976
# Epoch 184/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.2280 - accuracy: 0.9190
# Epoch 185/400
# 12/12 [==============================] - 4s 293ms/step - loss: 0.2025 - accuracy: 0.9405
# Epoch 186/400
# 12/12 [==============================] - 4s 299ms/step - loss: 0.1958 - accuracy: 0.9429
# Epoch 187/400
# 12/12 [==============================] - 4s 292ms/step - loss: 0.2162 - accuracy: 0.9143
# Epoch 188/400
# 12/12 [==============================] - 4s 311ms/step - loss: 0.2224 - accuracy: 0.9214
# Epoch 189/400
# 12/12 [==============================] - 3s 289ms/step - loss: 0.2419 - accuracy: 0.9190
# Epoch 190/400
# 12/12 [==============================] - 4s 307ms/step - loss: 0.2535 - accuracy: 0.9048
# Epoch 191/400
# 12/12 [==============================] - 3s 286ms/step - loss: 0.3175 - accuracy: 0.8857
# Epoch 192/400
# 12/12 [==============================] - 3s 276ms/step - loss: 0.1959 - accuracy: 0.9452
# Epoch 193/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.2231 - accuracy: 0.9214
# Epoch 194/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.1992 - accuracy: 0.9333
# Epoch 195/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.1900 - accuracy: 0.9262
# Epoch 196/400
# 12/12 [==============================] - 3s 245ms/step - loss: 0.1661 - accuracy: 0.9429
# Epoch 197/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.1794 - accuracy: 0.9405
# Epoch 198/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.1992 - accuracy: 0.9286
# Epoch 199/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.1708 - accuracy: 0.9381
# Epoch 200/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.2178 - accuracy: 0.9119
# Epoch 201/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.2117 - accuracy: 0.9310
# Epoch 202/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.1974 - accuracy: 0.9429
# Epoch 203/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1897 - accuracy: 0.9310
# Epoch 204/400
# 12/12 [==============================] - 3s 286ms/step - loss: 0.1688 - accuracy: 0.9500
# Epoch 205/400
# 12/12 [==============================] - 4s 303ms/step - loss: 0.2209 - accuracy: 0.9262
# Epoch 206/400
# 12/12 [==============================] - 5s 378ms/step - loss: 0.2264 - accuracy: 0.9214
# Epoch 207/400
# 12/12 [==============================] - 4s 338ms/step - loss: 0.2303 - accuracy: 0.9190
# Epoch 208/400
# 12/12 [==============================] - 4s 356ms/step - loss: 0.2408 - accuracy: 0.9095
# Epoch 209/400
# 12/12 [==============================] - 4s 305ms/step - loss: 0.2372 - accuracy: 0.9167
# Epoch 210/400
# 12/12 [==============================] - 3s 288ms/step - loss: 0.2023 - accuracy: 0.9357
# Epoch 211/400
# 12/12 [==============================] - 4s 295ms/step - loss: 0.1984 - accuracy: 0.9262
# Epoch 212/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.2480 - accuracy: 0.9071
# Epoch 213/400
# 12/12 [==============================] - 3s 285ms/step - loss: 0.1637 - accuracy: 0.9405
# Epoch 214/400
# 12/12 [==============================] - 3s 249ms/step - loss: 0.2205 - accuracy: 0.9262
# Epoch 215/400
# 12/12 [==============================] - 3s 262ms/step - loss: 0.2103 - accuracy: 0.9262
# Epoch 216/400
# 12/12 [==============================] - 4s 301ms/step - loss: 0.1923 - accuracy: 0.9286
# Epoch 217/400
# 12/12 [==============================] - 3s 282ms/step - loss: 0.2079 - accuracy: 0.9262
# Epoch 218/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.2137 - accuracy: 0.9214
# Epoch 219/400
# 12/12 [==============================] - 3s 249ms/step - loss: 0.1983 - accuracy: 0.9238
# Epoch 220/400
# 12/12 [==============================] - 3s 271ms/step - loss: 0.1633 - accuracy: 0.9476
# Epoch 221/400
# 12/12 [==============================] - 3s 273ms/step - loss: 0.1470 - accuracy: 0.9571
# Epoch 222/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.1588 - accuracy: 0.9524
# Epoch 223/400
# 12/12 [==============================] - 3s 280ms/step - loss: 0.1925 - accuracy: 0.9333
# Epoch 224/400
# 12/12 [==============================] - 3s 283ms/step - loss: 0.2147 - accuracy: 0.9262
# Epoch 225/400
# 12/12 [==============================] - 3s 292ms/step - loss: 0.1806 - accuracy: 0.9357
# Epoch 226/400
# 12/12 [==============================] - 3s 270ms/step - loss: 0.1614 - accuracy: 0.9429
# Epoch 227/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.2253 - accuracy: 0.9095
# Epoch 228/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.2244 - accuracy: 0.9190
# Epoch 229/400
# 12/12 [==============================] - 3s 281ms/step - loss: 0.3323 - accuracy: 0.9000
# Epoch 230/400
# 12/12 [==============================] - 4s 292ms/step - loss: 0.2906 - accuracy: 0.8881
# Epoch 231/400
# 12/12 [==============================] - 4s 292ms/step - loss: 0.2476 - accuracy: 0.9119
# Epoch 232/400
# 12/12 [==============================] - 3s 260ms/step - loss: 0.2550 - accuracy: 0.9143
# Epoch 233/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.1505 - accuracy: 0.9619
# Epoch 234/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.1781 - accuracy: 0.9476
# Epoch 235/400
# 12/12 [==============================] - 3s 256ms/step - loss: 0.1224 - accuracy: 0.9643
# Epoch 236/400
# 12/12 [==============================] - 3s 260ms/step - loss: 0.1455 - accuracy: 0.9500
# Epoch 237/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.1447 - accuracy: 0.9548
# Epoch 238/400
# 12/12 [==============================] - 3s 274ms/step - loss: 0.1638 - accuracy: 0.9524
# Epoch 239/400
# 12/12 [==============================] - 4s 294ms/step - loss: 0.1597 - accuracy: 0.9548
# Epoch 240/400
# 12/12 [==============================] - 4s 299ms/step - loss: 0.1503 - accuracy: 0.9500
# Epoch 241/400
# 12/12 [==============================] - 4s 304ms/step - loss: 0.2004 - accuracy: 0.9333
# Epoch 242/400
# 12/12 [==============================] - 4s 308ms/step - loss: 0.1764 - accuracy: 0.9357
# Epoch 243/400
# 12/12 [==============================] - 3s 283ms/step - loss: 0.1765 - accuracy: 0.9310
# Epoch 244/400
# 12/12 [==============================] - 3s 288ms/step - loss: 0.1787 - accuracy: 0.9476
# Epoch 245/400
# 12/12 [==============================] - 3s 269ms/step - loss: 0.1355 - accuracy: 0.9524
# Epoch 246/400
# 12/12 [==============================] - 3s 263ms/step - loss: 0.1319 - accuracy: 0.9595
# Epoch 247/400
# 12/12 [==============================] - 3s 253ms/step - loss: 0.1496 - accuracy: 0.9476
# Epoch 248/400
# 12/12 [==============================] - 3s 256ms/step - loss: 0.1108 - accuracy: 0.9667
# Epoch 249/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.1264 - accuracy: 0.9571
# Epoch 250/400
# 12/12 [==============================] - 3s 253ms/step - loss: 0.1465 - accuracy: 0.9476
# Epoch 251/400
# 12/12 [==============================] - 3s 264ms/step - loss: 0.1651 - accuracy: 0.9357
# Epoch 252/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.1395 - accuracy: 0.9524
# Epoch 253/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.1804 - accuracy: 0.9476
# Epoch 254/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.1458 - accuracy: 0.9476
# Epoch 255/400
# 12/12 [==============================] - 3s 270ms/step - loss: 0.1970 - accuracy: 0.9405
# Epoch 256/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1370 - accuracy: 0.9571
# Epoch 257/400
# 12/12 [==============================] - 3s 275ms/step - loss: 0.1335 - accuracy: 0.9571
# Epoch 258/400
# 12/12 [==============================] - 3s 268ms/step - loss: 0.1283 - accuracy: 0.9571
# Epoch 259/400
# 12/12 [==============================] - 3s 242ms/step - loss: 0.1649 - accuracy: 0.9452
# Epoch 260/400
# 12/12 [==============================] - 3s 249ms/step - loss: 0.1963 - accuracy: 0.9381
# Epoch 261/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.1590 - accuracy: 0.9381
# Epoch 262/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.1579 - accuracy: 0.9429
# Epoch 263/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.1704 - accuracy: 0.9476
# Epoch 264/400
# 12/12 [==============================] - 3s 277ms/step - loss: 0.1518 - accuracy: 0.9571
# Epoch 265/400
# 12/12 [==============================] - 3s 267ms/step - loss: 0.1631 - accuracy: 0.9452
# Epoch 266/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1354 - accuracy: 0.9500
# Epoch 267/400
# 12/12 [==============================] - 3s 264ms/step - loss: 0.1875 - accuracy: 0.9310
# Epoch 268/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1360 - accuracy: 0.9571
# Epoch 269/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.1195 - accuracy: 0.9619
# Epoch 270/400
# 12/12 [==============================] - 3s 238ms/step - loss: 0.1113 - accuracy: 0.9643
# Epoch 271/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.1140 - accuracy: 0.9643
# Epoch 272/400
# 12/12 [==============================] - 3s 260ms/step - loss: 0.1302 - accuracy: 0.9571
# Epoch 273/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.1390 - accuracy: 0.9452
# Epoch 274/400
# 12/12 [==============================] - 3s 267ms/step - loss: 0.2027 - accuracy: 0.9286
# Epoch 275/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1577 - accuracy: 0.9452
# Epoch 276/400
# 12/12 [==============================] - 3s 277ms/step - loss: 0.2571 - accuracy: 0.9048
# Epoch 277/400
# 12/12 [==============================] - 3s 226ms/step - loss: 0.2194 - accuracy: 0.9286
# Epoch 278/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.2388 - accuracy: 0.9048
# Epoch 279/400
# 12/12 [==============================] - 3s 238ms/step - loss: 0.1797 - accuracy: 0.9452
# Epoch 280/400
# 12/12 [==============================] - 3s 211ms/step - loss: 0.1655 - accuracy: 0.9381
# Epoch 281/400
# 12/12 [==============================] - 3s 217ms/step - loss: 0.1629 - accuracy: 0.9405
# Epoch 282/400
# 12/12 [==============================] - 3s 230ms/step - loss: 0.1020 - accuracy: 0.9714
# Epoch 283/400
# 12/12 [==============================] - 3s 256ms/step - loss: 0.0974 - accuracy: 0.9786
# Epoch 284/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.1085 - accuracy: 0.9690
# Epoch 285/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.0937 - accuracy: 0.9714
# Epoch 286/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.1120 - accuracy: 0.9595
# Epoch 287/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.1238 - accuracy: 0.9643
# Epoch 288/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.1447 - accuracy: 0.9405
# Epoch 289/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.1332 - accuracy: 0.9571
# Epoch 290/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.1095 - accuracy: 0.9690
# Epoch 291/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.1080 - accuracy: 0.9667
# Epoch 292/400
# 12/12 [==============================] - 3s 232ms/step - loss: 0.1186 - accuracy: 0.9429
# Epoch 293/400
# 12/12 [==============================] - 3s 225ms/step - loss: 0.0916 - accuracy: 0.9762
# Epoch 294/400
# 12/12 [==============================] - 3s 221ms/step - loss: 0.1229 - accuracy: 0.9571
# Epoch 295/400
# 12/12 [==============================] - 3s 220ms/step - loss: 0.1130 - accuracy: 0.9667
# Epoch 296/400
# 12/12 [==============================] - 3s 223ms/step - loss: 0.1364 - accuracy: 0.9548
# Epoch 297/400
# 12/12 [==============================] - 3s 219ms/step - loss: 0.1166 - accuracy: 0.9548
# Epoch 298/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.1164 - accuracy: 0.9476
# Epoch 299/400
# 12/12 [==============================] - 3s 233ms/step - loss: 0.1002 - accuracy: 0.9619
# Epoch 300/400
# 12/12 [==============================] - 3s 227ms/step - loss: 0.1330 - accuracy: 0.9429
# Epoch 301/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.1107 - accuracy: 0.9595
# Epoch 302/400
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0978 - accuracy: 0.9762
# Epoch 303/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.0674 - accuracy: 0.9857
# Epoch 304/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.1204 - accuracy: 0.9571
# Epoch 305/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1374 - accuracy: 0.9500
# Epoch 306/400
# 12/12 [==============================] - 3s 247ms/step - loss: 0.1579 - accuracy: 0.9500
# Epoch 307/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1062 - accuracy: 0.9643
# Epoch 308/400
# 12/12 [==============================] - 3s 254ms/step - loss: 0.0652 - accuracy: 0.9881
# Epoch 309/400
# 12/12 [==============================] - 3s 250ms/step - loss: 0.0862 - accuracy: 0.9643
# Epoch 310/400
# 12/12 [==============================] - 3s 242ms/step - loss: 0.1130 - accuracy: 0.9595
# Epoch 311/400
# 12/12 [==============================] - 3s 233ms/step - loss: 0.1736 - accuracy: 0.9357
# Epoch 312/400
# 12/12 [==============================] - 3s 232ms/step - loss: 0.1461 - accuracy: 0.9500
# Epoch 313/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.1368 - accuracy: 0.9595
# Epoch 314/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.1037 - accuracy: 0.9667
# Epoch 315/400
# 12/12 [==============================] - 3s 246ms/step - loss: 0.1283 - accuracy: 0.9619
# Epoch 316/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.1557 - accuracy: 0.9548
# Epoch 317/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1648 - accuracy: 0.9500
# Epoch 318/400
# 12/12 [==============================] - 3s 246ms/step - loss: 0.1266 - accuracy: 0.9643
# Epoch 319/400
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1134 - accuracy: 0.9643
# Epoch 320/400
# 12/12 [==============================] - 3s 273ms/step - loss: 0.0962 - accuracy: 0.9738
# Epoch 321/400
# 12/12 [==============================] - 3s 291ms/step - loss: 0.0769 - accuracy: 0.9762
# Epoch 322/400
# 12/12 [==============================] - 4s 309ms/step - loss: 0.1061 - accuracy: 0.9690
# Epoch 323/400
# 12/12 [==============================] - 4s 295ms/step - loss: 0.0948 - accuracy: 0.9667
# Epoch 324/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.1062 - accuracy: 0.9619
# Epoch 325/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.0894 - accuracy: 0.9643
# Epoch 326/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.1034 - accuracy: 0.9595
# Epoch 327/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.1653 - accuracy: 0.9571
# Epoch 328/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.2136 - accuracy: 0.9262
# Epoch 329/400
# 12/12 [==============================] - 3s 264ms/step - loss: 0.2318 - accuracy: 0.9167
# Epoch 330/400
# 12/12 [==============================] - 4s 303ms/step - loss: 0.1642 - accuracy: 0.9571
# Epoch 331/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.1210 - accuracy: 0.9548
# Epoch 332/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0941 - accuracy: 0.9762
# Epoch 333/400
# 12/12 [==============================] - 4s 304ms/step - loss: 0.0906 - accuracy: 0.9643
# Epoch 334/400
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0899 - accuracy: 0.9714
# Epoch 335/400
# 12/12 [==============================] - 3s 274ms/step - loss: 0.0743 - accuracy: 0.9786
# Epoch 336/400
# 12/12 [==============================] - 4s 292ms/step - loss: 0.0632 - accuracy: 0.9857
# Epoch 337/400
# 12/12 [==============================] - 3s 268ms/step - loss: 0.0560 - accuracy: 0.9881
# Epoch 338/400
# 12/12 [==============================] - 3s 261ms/step - loss: 0.0723 - accuracy: 0.9762
# Epoch 339/400
# 12/12 [==============================] - 3s 262ms/step - loss: 0.0543 - accuracy: 0.9881
# Epoch 340/400
# 12/12 [==============================] - 4s 313ms/step - loss: 0.0805 - accuracy: 0.9762
# Epoch 341/400
# 12/12 [==============================] - 3s 283ms/step - loss: 0.0639 - accuracy: 0.9786
# Epoch 342/400
# 12/12 [==============================] - 3s 277ms/step - loss: 0.0816 - accuracy: 0.9810
# Epoch 343/400
# 12/12 [==============================] - 3s 284ms/step - loss: 0.0807 - accuracy: 0.9786
# Epoch 344/400
# 12/12 [==============================] - 3s 255ms/step - loss: 0.0898 - accuracy: 0.9643
# Epoch 345/400
# 12/12 [==============================] - 3s 247ms/step - loss: 0.1006 - accuracy: 0.9667
# Epoch 346/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.0911 - accuracy: 0.9714
# Epoch 347/400
# 12/12 [==============================] - 3s 269ms/step - loss: 0.0853 - accuracy: 0.9714
# Epoch 348/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.1034 - accuracy: 0.9690
# Epoch 349/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.0754 - accuracy: 0.9786
# Epoch 350/400
# 12/12 [==============================] - 3s 253ms/step - loss: 0.0740 - accuracy: 0.9810
# Epoch 351/400
# 12/12 [==============================] - 3s 253ms/step - loss: 0.0881 - accuracy: 0.9714
# Epoch 352/400
# 12/12 [==============================] - 3s 256ms/step - loss: 0.0849 - accuracy: 0.9690
# Epoch 353/400
# 12/12 [==============================] - 3s 244ms/step - loss: 0.1235 - accuracy: 0.9548
# Epoch 354/400
# 12/12 [==============================] - 3s 268ms/step - loss: 0.1347 - accuracy: 0.9452
# Epoch 355/400
# 12/12 [==============================] - 3s 271ms/step - loss: 0.1494 - accuracy: 0.9452
# Epoch 356/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.2482 - accuracy: 0.9119
# Epoch 357/400
# 12/12 [==============================] - 3s 270ms/step - loss: 0.1301 - accuracy: 0.9524
# Epoch 358/400
# 12/12 [==============================] - 3s 278ms/step - loss: 0.0931 - accuracy: 0.9762
# Epoch 359/400
# 12/12 [==============================] - 3s 285ms/step - loss: 0.1178 - accuracy: 0.9619
# Epoch 360/400
# 12/12 [==============================] - 3s 284ms/step - loss: 0.1353 - accuracy: 0.9571
# Epoch 361/400
# 12/12 [==============================] - 3s 270ms/step - loss: 0.0901 - accuracy: 0.9738
# Epoch 362/400
# 12/12 [==============================] - 4s 303ms/step - loss: 0.0932 - accuracy: 0.9738
# Epoch 363/400
# 12/12 [==============================] - 4s 314ms/step - loss: 0.0762 - accuracy: 0.9786
# Epoch 364/400
# 12/12 [==============================] - 4s 298ms/step - loss: 0.0809 - accuracy: 0.9690
# Epoch 365/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.0662 - accuracy: 0.9833
# Epoch 366/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.0633 - accuracy: 0.9833
# Epoch 367/400
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0676 - accuracy: 0.9762
# Epoch 368/400
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0715 - accuracy: 0.9786
# Epoch 369/400
# 12/12 [==============================] - 3s 290ms/step - loss: 0.0559 - accuracy: 0.9881
# Epoch 370/400
# 12/12 [==============================] - 3s 257ms/step - loss: 0.0662 - accuracy: 0.9786
# Epoch 371/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.0811 - accuracy: 0.9690
# Epoch 372/400
# 12/12 [==============================] - 3s 279ms/step - loss: 0.1025 - accuracy: 0.9643
# Epoch 373/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.1644 - accuracy: 0.9405
# Epoch 374/400
# 12/12 [==============================] - 3s 241ms/step - loss: 0.1167 - accuracy: 0.9571
# Epoch 375/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.0939 - accuracy: 0.9738
# Epoch 376/400
# 12/12 [==============================] - 3s 258ms/step - loss: 0.0959 - accuracy: 0.9762
# Epoch 377/400
# 12/12 [==============================] - 3s 267ms/step - loss: 0.0912 - accuracy: 0.9690
# Epoch 378/400
# 12/12 [==============================] - 3s 259ms/step - loss: 0.0802 - accuracy: 0.9643
# Epoch 379/400
# 12/12 [==============================] - 3s 248ms/step - loss: 0.0781 - accuracy: 0.9786
# Epoch 380/400
# 12/12 [==============================] - 3s 249ms/step - loss: 0.0654 - accuracy: 0.9810
# Epoch 381/400
# 12/12 [==============================] - 3s 236ms/step - loss: 0.0779 - accuracy: 0.9714
# Epoch 382/400
# 12/12 [==============================] - 3s 239ms/step - loss: 0.0896 - accuracy: 0.9643
# Epoch 383/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.0967 - accuracy: 0.9714
# Epoch 384/400
# 12/12 [==============================] - 3s 234ms/step - loss: 0.1019 - accuracy: 0.9690
# Epoch 385/400
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0632 - accuracy: 0.9810
# Epoch 386/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.0602 - accuracy: 0.9833
# Epoch 387/400
# 12/12 [==============================] - 3s 243ms/step - loss: 0.0507 - accuracy: 0.9857
# Epoch 388/400
# 12/12 [==============================] - 3s 231ms/step - loss: 0.0665 - accuracy: 0.9762
# Epoch 389/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.0495 - accuracy: 0.9833
# Epoch 390/400
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0423 - accuracy: 0.9905
# Epoch 391/400
# 12/12 [==============================] - 3s 246ms/step - loss: 0.0908 - accuracy: 0.9714
# Epoch 392/400
# 12/12 [==============================] - 3s 240ms/step - loss: 0.0753 - accuracy: 0.9738
# Epoch 393/400
# 12/12 [==============================] - 3s 252ms/step - loss: 0.0950 - accuracy: 0.9738
# Epoch 394/400
# 12/12 [==============================] - 3s 237ms/step - loss: 0.1567 - accuracy: 0.9524
# Epoch 395/400
# 12/12 [==============================] - 3s 229ms/step - loss: 0.0823 - accuracy: 0.9762
# Epoch 396/400
# 12/12 [==============================] - 3s 234ms/step - loss: 0.0711 - accuracy: 0.9786
# Epoch 397/400
# 12/12 [==============================] - 3s 265ms/step - loss: 0.0740 - accuracy: 0.9762
# Epoch 398/400
# 12/12 [==============================] - 3s 288ms/step - loss: 0.0999 - accuracy: 0.9548
# Epoch 399/400
# 12/12 [==============================] - 3s 278ms/step - loss: 0.0577 - accuracy: 0.9833
# Epoch 400/400
# 12/12 [==============================] - 3s 291ms/step - loss: 0.0642 - accuracy: 0.9786
#
# Validating ...
# 4/4 [==============================] - 0s 46ms/step - loss: 1.7791 - accuracy: 0.5500
# Dev loss:   1.7790942192077637
# Dev accuracy:   0.550000011920929
#
# Testing ...
# 2/2 [==============================] - 0s 29ms/step - loss: 2.6815 - accuracy: 0.4833
# Test loss:   2.6814866065979004
# Test accuracy:   0.4833333194255829
#
# Saving model: lstm_genre_classifier_lstm.h5
